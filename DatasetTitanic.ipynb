# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sex_col = "Sex"
age_col = "Age"
pclass_col = "Pclass"
new_col = "new_age"
surv_col = "Survived"

data = pd.read_csv('../Desktop/train.csv')
sns.set_theme(style='darkgrid')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
table_with_male = data.where(data['Sex']=='male')
#del table_with_male['new_age'] #--Удаление feature
table_with_male
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 0            1.0       0.0     3.0   Braund, Mr. Owen Harris  male  22.0
# 1            NaN       NaN     NaN                       NaN   NaN   NaN
# 2            NaN       NaN     NaN                       NaN   NaN   NaN
# 3            NaN       NaN     NaN                       NaN   NaN   NaN
# 4            5.0       0.0     3.0  Allen, Mr. William Henry  male  35.0
# ..           ...       ...     ...                       ...   ...   ...
# 886        887.0       0.0     2.0     Montvila, Rev. Juozas  male  27.0
# 887          NaN       NaN     NaN                       NaN   NaN   NaN
# 888          NaN       NaN     NaN                       NaN   NaN   NaN
# 889        890.0       1.0     1.0     Behr, Mr. Karl Howell  male  26.0
# 890        891.0       0.0     3.0       Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch     Ticket   Fare Cabin Embarked
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data[sex_col].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
data[age_col].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data[new_col] = data[age_col]
data[new_col].fillna(-1, inplace=True) #Заливаем все NaN значением -1
data[new_col] = data[new_col].map(lambda age: int(age //10) + 1) #мат операции ко всему feature

# %%
data[new_col].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='new_age'>

# %%
print(data.shape)
data.info()
# Out:
# (891, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  new_age      891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
data['Survived'] = data['Survived'].astype('bool')
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    bool
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  new_age      891 non-null    int64
# dtypes: bool(1), float64(2), int64(5), object(5)
# memory usage: 84.5+ KB
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# ...

# %%
data['Sex'].value_counts(normalize=True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data.sort_values(by=['Name'],  ascending=False).head() #  ascending=False -- обратный порядок
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 868          869     False       3      van Melkebeke, Mr. Philemon  male
# 153          154     False       3  van Billiard, Mr. Austin Blyler  male
# 361          362     False       2        del Carlo, Mr. Sebastiano  male
# 282          283     False       3        de Pelsmaeker, Mr. Alfons  male
# 286          287      True       3          de Mulder, Mr. Theodore  male
#
#       Age  SibSp  Parch         Ticket     Fare Cabin Embarked  new_age
# 868   NaN      0      0         345777   9.5000   NaN        S        0
# 153  40.5      0      2       A/5. 851  14.5000   NaN        S        5
# 361  29.0      1      0  SC/PARIS 2167  27.7208   NaN        C        3
# 282  16.0      0      0         345778   9.5000   NaN        S        2
# 286  30.0      0      0         345774   9.5000   NaN        S        4

# %%
data[age_col].mean()
# Out:
# 29.69911764705882

# %%
male_by_surv = data[(data['Sex']=='male') & (data['Survived']==True)]
sns.histplot(x=male_by_surv['Age'], kde=True, bins=30)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# # Заданная функция считает количество значений в каждой категории

# %%
sns.countplot(x=data.Sex, hue=data.Pclass, data=data)
plt.show()

# %%
sns.histplot(data=data[['Age']], bins=30, kde=True, stat='count')
plt.show()
